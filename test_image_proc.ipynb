# %%
import pytesseract
from PIL import Image
import os
import ocr_processing 
import importlib
import matplotlib.pyplot as plt

# Remplacez le chemin par le chemin absolu de votre dossier "error"
folder_path = "error"
param = '--psm 6 -c tessedit_char_whitelist=0123456789-=+÷ tessedit_char_blacklist=/'
# Fonction pour traiter chaque image et extraire le texte
def process_images(folder_path):
    for filename in os.listdir(folder_path):
        if filename.endswith(".png") or filename.endswith(".jpg") or filename.endswith(".jpeg"):
            image_path = os.path.join(folder_path, filename)
            try:
                image = Image.open(image_path)
                tresh = ocr_processing.image_processing(image)
                print(pytesseract.image_to_string(tresh, config=param))
                display(image)
                plt.imshow(tresh)
                text = pytesseract.image_to_string(image, config=param)
                print(f"Texte extrait de {filename} :\n{text}\n")
            except Exception as e:
                print(f"Erreur lors du traitement de {filename}: {e}")

# Exécute la fonction
process_images(folder_path)
# Out:
# 61+30=
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=258x100>
# Texte extrait de Capture d'écran 2024-11-07 163337.png :
# 61+30=
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=882x97>
# Texte extrait de screenshot_20241107-161547.png :
# 378=6=
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=882x97>
# Texte extrait de screenshot_20241107-161631.png :
# 60-5=
#
#
# 113-26
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=243x82>
# Texte extrait de screenshot_20241107-164224.png :
# 113-26
#
#
# 19+27
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=217x85>
# Texte extrait de screenshot_20241107-182459.png :
# 19+27
#
#
# 286=11
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=239x85>
# Texte extrait de screenshot_20241107-212446.png :
# 286=11
#
#
# 75+3
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=209x75>
# Texte extrait de screenshot_20241107-212904.png :
# 15+3

# %%
import pytesseract
from PIL import Image
import pandas as pd
from ocr_processing import image_processing
importlib.reload(ocr_processing)
import matplotlib.pyplot as plt

# Load the image
folder_path = "error"
image_name = os.listdir(folder_path)[4]
image_path = os.path.join(folder_path, image_name)
image = Image.open(image_path)
tresh = image_processing(image)
text = pytesseract.image_to_string(tresh, config=param)
print(text)
display(image)
plt.imshow(tresh)
# Out:
# 19+27
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=217x85>

# %%
import cv2
import pytesseract

folder_path = "error"
image_name = os.listdir(folder_path)[1]
image_path = os.path.join(folder_path, image_name)
image = cv2.imread(image_path)
if image is None:
    print(f"Failed to load image: {image_path}")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

_, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY_INV)

custom_config = r'--oem 3 --psm 6' 

text = pytesseract.image_to_string(thresh, config=custom_config)
print(text)
plt.imshow(image)
# Out:
# 3/+6

# %%
import easyocr

# Create an OCR reader object
reader = easyocr.Reader(['en'])

folder_path = "test"
image_name = os.listdir(folder_path)[1]
image_path = os.path.join(folder_path, image_name)

# Read text from an image
result = reader.readtext(image_path)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
result
# Out:
# [([[32, 44], [234, 44], [234, 98], [32, 98]], '2 * 35 =', 0.5008470613322624),
#  ([[250, 46], [292, 46], [292, 76], [250, 76]], '22', 0.9997286259264415)]

# %%
f_results = [result for _, result, _ in results]

# %%
"".join(f_results)
# Out:
# '570204+846'

# %%
reader = easyocr.Reader(['ch_sim'])  # Specify the languages you want to recognize

folder_path = "error"
for image_name in os.listdir(folder_path)[-3:]:
    image_path = os.path.join(folder_path, image_name)
    image = cv2.imread(image_path)

    # Perform OCR directly on the image array
    results = reader.readtext(image)
    f_results = "".join([result for _, result, _ in results])
    print(f_results)
    plt.imshow(image)
    plt.show()
    print(results)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 570204'846
# [([[39, 13], [231, 13], [231, 73], [39, 73]], '570204', 0.9999935272857994), ([[238, 28], [268, 28], [268, 58], [238, 58]], "'", 0.010869451101428673), ([[278, 14], [380, 14], [380, 70], [278, 70]], '846', 0.6865988373756409)]
# 5548
# [([[201, 35], [377, 35], [377, 167], [201, 167]], '55', 0.9999886203698664), ([[513, 33], [689, 33], [689, 165], [513, 165]], '48', 0.9999489184017407)]
# 16-7
# [([[51, 35], [449, 35], [449, 169], [51, 169]], '16-7', 0.573850154876709)]
